# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dat = np.loadtxt('./pldm-sampled-spinBoson.txt')
plt.plot(dat[:,0], dat[:,1], label='Re')

dat = np.loadtxt('./mfe-spinBoson.txt')
plt.plot(dat[:,0], dat[:,1], label='Re')

dat = np.loadtxt('./pldm-focused-spinBoson.txt')
plt.plot(dat[:,0], dat[:,1], label='Re')
